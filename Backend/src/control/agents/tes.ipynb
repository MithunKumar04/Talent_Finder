# %%
from src.control.agents.resume_parser import resume_parser
from src.control.agents.resume_extractor import resume_extractor
from jd_extractor import jd_extractor
from src.control.agents.embedding import get_embedding
from src.control.agents.scoring_agent import create_scores
from src.control.agents.explanation_builder import build_candidate_explanation_llm

# %%
llm.invoke("Vanakkam")
# Out:
# AIMessage(content='Vanakkam! 😊 \n\nThat’s a beautiful Tamil greeting! It means “Hello” or “Greetings.” \n\nHow are you doing today? Is there anything I can help you with?', additional_kwargs={}, response_metadata={'model': 'gemma3', 'created_at': '2026-02-27T07:08:56.1973478Z', 'done': True, 'done_reason': 'stop', 'total_duration': 5208728500, 'load_duration': 489409100, 'prompt_eval_count': 11, 'prompt_eval_duration': 3369900800, 'eval_count': 41, 'eval_duration': 1317603800, 'logprobs': None, 'model_name': 'gemma3', 'model_provider': 'ollama'}, id='lc_run--019c9ded-c3a2-7b72-b639-b07603413983-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 11, 'output_tokens': 41, 'total_tokens': 52})
